# %%
#11_A
import random
class Dice:
    def __init__(self, numbers):
        self.dice=[i for i in numbers]
        self.workspace=[i for i in numbers]
        
        self.top=self.dice[0]
        
        
    def rotate(self,command):
        if command == "W":
            self.workspace=[self.dice[2], self.dice[1], self.dice[5], self.dice[0], self.dice[4], self.dice[3]]
            self.dice=self.workspace
        elif command == "E":
            self.workspace=[self.dice[3], self.dice[1], self.dice[0], self.dice[5], self.dice[4], self.dice[2]]
            self.dice = self.workspace
        
        if command == "S":
            self.workspace=[self.dice[4], self.dice[0], self.dice[2], self.dice[3], self.dice[5], self.dice[1]]
            self.dice=self.workspace
        elif command == "N":
            self.workspace=[self.dice[1], self.dice[5], self.dice[2], self.dice[3], self.dice[0], self.dice[4]]
            self.dice=self.workspace
            
    def get_top(self):
        self.top=self.dice[0]
        print(self.top)
        
#     def predict(self, num):
#         for i in range(num):
#             top, front = map(int, input().split())
#             while(True):
#                 if top == self.dice[0] and front == self.dice[1]:
#                     break
#                 command_num=random.randint(1,4)
#                 if command_num == 1:
#                     self.rotate("W")
#                 elif command_num == 2:
#                     self.rotate("E")
#                 elif command_num == 3:
#                     self.rotate("S")
#                 elif command_num == 4:
#                     self.rotate("N")
#             print(self.dice[2])
            
#     def getter(self):
#         return self.dice[0], self.dice[1], self.dice[2], self.dice[3], self.dice[4], self.dice[5]
    
#     def predict_same(self, top, front, right, left, back, bottom, num=50000):
#         for n in range(num):
#             if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
#                 break
#             command_num=random.randint(1,4)
#             if command_num == 1:
#                     self.rotate("W")
#             elif command_num == 2:
#                     self.rotate("E")
#             elif command_num == 3:
#                     self.rotate("S")
#             elif command_num == 4:
#                     self.rotate("N")
        
#         if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
#             if self.dice[3] == left and self.dice[4] == back and self.dice[5] == bottom:
#                 return "Yes"
                
#             else:
#                 return "No"
                
#         else:
#             return "No"
            
        
            
                
    
        
numbers=list(map(int,input().split()))
dice=Dice(numbers)
commands=input()
for i in range(len(commands)):
    dice.rotate(commands[i])
dice.get_top()
# Out:
# 1 2 4 8 16 32
# SE
# 8

# %%
#11_B
import random
class Dice:
    def __init__(self, numbers):
        self.dice=[i for i in numbers]
        self.workspace=[i for i in numbers]
        
        self.top=self.dice[0]
        
        
    def rotate(self,command):
        if command == "W":
            self.workspace=[self.dice[2], self.dice[1], self.dice[5], self.dice[0], self.dice[4], self.dice[3]]
            self.dice=self.workspace
        elif command == "E":
            self.workspace=[self.dice[3], self.dice[1], self.dice[0], self.dice[5], self.dice[4], self.dice[2]]
            self.dice = self.workspace
        
        if command == "S":
            self.workspace=[self.dice[4], self.dice[0], self.dice[2], self.dice[3], self.dice[5], self.dice[1]]
            self.dice=self.workspace
        elif command == "N":
            self.workspace=[self.dice[1], self.dice[5], self.dice[2], self.dice[3], self.dice[0], self.dice[4]]
            self.dice=self.workspace
            
    def get_top(self):
        self.top=self.dice[0]
        print(self.top)
        
    def predict(self, num): #以降追加
        for i in range(num):
            top, front = map(int, input().split())
            while(True):
                if top == self.dice[0] and front == self.dice[1]:
                    break
                command_num=random.randint(1,4)
                if command_num == 1:
                    self.rotate("W")
                elif command_num == 2:
                    self.rotate("E")
                elif command_num == 3:
                    self.rotate("S")
                elif command_num == 4:
                    self.rotate("N")
            print(self.dice[2])
            
#     def getter(self):
#         return self.dice[0], self.dice[1], self.dice[2], self.dice[3], self.dice[4], self.dice[5]
    
#     def predict_same(self, top, front, right, left, back, bottom, num=50000):
#         for n in range(num):
#             if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
#                 break
#             command_num=random.randint(1,4)
#             if command_num == 1:
#                     self.rotate("W")
#             elif command_num == 2:
#                     self.rotate("E")
#             elif command_num == 3:
#                     self.rotate("S")
#             elif command_num == 4:
#                     self.rotate("N")
        
#         if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
#             if self.dice[3] == left and self.dice[4] == back and self.dice[5] == bottom:
#                 return "Yes"
                
#             else:
#                 return "No"
                
#         else:
#             return "No"
        
        
##main##        
numbers=list(map(int,input().split()))
dice=Dice(numbers)
q=int(input())
dice.predict(q)
# Out:
# 1 2 3 4 5 6
# 3
# 6 5
# 3
# 1 3
# 5
# 3 2
# 6

# %%
##11_C
import random
class Dice:
    def __init__(self, numbers):
        self.dice=[i for i in numbers]
        self.workspace=[i for i in numbers]
        
        self.top=self.dice[0]
        
        
    def rotate(self,command):
        if command == "W":
            self.workspace=[self.dice[2], self.dice[1], self.dice[5], self.dice[0], self.dice[4], self.dice[3]]
            self.dice=self.workspace
        elif command == "E":
            self.workspace=[self.dice[3], self.dice[1], self.dice[0], self.dice[5], self.dice[4], self.dice[2]]
            self.dice = self.workspace
        
        if command == "S":
            self.workspace=[self.dice[4], self.dice[0], self.dice[2], self.dice[3], self.dice[5], self.dice[1]]
            self.dice=self.workspace
        elif command == "N":
            self.workspace=[self.dice[1], self.dice[5], self.dice[2], self.dice[3], self.dice[0], self.dice[4]]
            self.dice=self.workspace
            
    def get_top(self):
        self.top=self.dice[0]
        print(self.top)
        
    def predict(self, num):
        for i in range(num):
            top, front = map(int, input().split())
            while(True):
                if top == self.dice[0] and front == self.dice[1]:
                    break
                command_num=random.randint(1,4)
                if command_num == 1:
                    self.rotate("W")
                elif command_num == 2:
                    self.rotate("E")
                elif command_num == 3:
                    self.rotate("S")
                elif command_num == 4:
                    self.rotate("N")
            print(self.dice[2])
            
    def getter(self): #追加
        return self.dice[0], self.dice[1], self.dice[2], self.dice[3], self.dice[4], self.dice[5]
    
    def predict_same(self, top, front, right, left, back, bottom, num=50000): #追加
        for n in range(num):
            if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
                break
            command_num=random.randint(1,4)
            if command_num == 1:
                    self.rotate("W")
            elif command_num == 2:
                    self.rotate("E")
            elif command_num == 3:
                    self.rotate("S")
            elif command_num == 4:
                    self.rotate("N")
        
        if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
            if self.dice[3] == left and self.dice[4] == back and self.dice[5] == bottom:
                return "Yes"
                
            else:
                return "No"
                
        else:
            return "No"
        
        
##main##        
numbers1=list(map(int,input().split()))
numbers2=list(map(int,input().split()))
dice1=Dice(numbers1)
dice2=Dice(numbers2)
top, front, right, left, back, bottom=dice1.getter()

print(dice2.predict_same(top, front, right, left, back, bottom))
# Out:
# 1 2 3 4 5 6
# 6 2 4 3 5 1
# Yes

# %%
#11_D
import random
class Dice:
    def __init__(self, numbers):
        self.dice=[i for i in numbers]
        self.workspace=[i for i in numbers]
        
        self.top=self.dice[0]
        
        
    def rotate(self,command):
        if command == "W":
            self.workspace=[self.dice[2], self.dice[1], self.dice[5], self.dice[0], self.dice[4], self.dice[3]]
            self.dice=self.workspace
        elif command == "E":
            self.workspace=[self.dice[3], self.dice[1], self.dice[0], self.dice[5], self.dice[4], self.dice[2]]
            self.dice = self.workspace
        
        if command == "S":
            self.workspace=[self.dice[4], self.dice[0], self.dice[2], self.dice[3], self.dice[5], self.dice[1]]
            self.dice=self.workspace
        elif command == "N":
            self.workspace=[self.dice[1], self.dice[5], self.dice[2], self.dice[3], self.dice[0], self.dice[4]]
            self.dice=self.workspace
            
    def get_top(self):
        self.top=self.dice[0]
        print(self.top)
        
    def predict(self, num):
        for i in range(num):
            top, front = map(int, input().split())
            while(True):
                if top == self.dice[0] and front == self.dice[1]:
                    break
                command_num=random.randint(1,4)
                if command_num == 1:
                    self.rotate("W")
                elif command_num == 2:
                    self.rotate("E")
                elif command_num == 3:
                    self.rotate("S")
                elif command_num == 4:
                    self.rotate("N")
            print(self.dice[2])
            
    def getter(self):
        return self.dice[0], self.dice[1], self.dice[2], self.dice[3], self.dice[4], self.dice[5]
    
    def predict_same(self, top, front, right, left, back, bottom, num=50000):
        for n in range(num):
            if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
                break
            command_num=random.randint(1,4)
            if command_num == 1:
                    self.rotate("W")
            elif command_num == 2:
                    self.rotate("E")
            elif command_num == 3:
                    self.rotate("S")
            elif command_num == 4:
                    self.rotate("N")
        
        if top ==self.dice[0] and front== self.dice[1] and right ==self.dice[2]:
            if self.dice[3] == left and self.dice[4] == back and self.dice[5] == bottom:
                return "Yes"
                
            else:
                return "No"
                
        else:
            return "No"
        
      
q=int(input())
list_dice=[]
judges=[]

for i in range(q):
    numbers=list(map(int, input().split()))
    dice=Dice(numbers)
    list_dice.append(dice)
i=0
while(True):
    if (i+1) == len(list_dice):
        break
    for n in range(i+1,len(list_dice)):
        top, front, right, left, back, bottom=list_dice[i].getter()
        judges.append(list_dice[n].predict_same(top, front, right, left, back, bottom, num=300)) 
    i+=1
    
if "Yes" in judges:
    print("No")
else:
    print("Yes")
# Out:
# 3
# 1 2 3 4 5 6
# 6 5 4 3 2 1
# 5 4 3 2 1 6
# Yes

# %%
# Out:
# [1, 24, 8, 16, 32]
